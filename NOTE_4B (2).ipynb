# %%
from urllib.request import urlretrieve

# %%
urlretrieve('https://raw.githubusercontent.com/JovianML/opendatasets/master/data/stackoverflow-developer-survey-2020/survey_results_public.csv ',
            'result.csv'
)
# Out:
# ('result.csv', <http.client.HTTPMessage at 0x7964181012a0>)

# %%
urlretrieve('https://raw.githubusercontent.com/JovianML/opendatasets/master/data/stackoverflow-developer-survey-2020/survey_results_schema.csv',
            'survey_results_schema.csv')
# Out:
# ('survey_results_schema.csv', <http.client.HTTPMessage at 0x7964181014b0>)

# %%
import os

# %%
os.listdir()
# Out:
# ['.config', 'survey_results_schema.csv', 'result.csv', 'sample_data']

# %%
import pandas as pd

# %%
df = pd.read_csv('result.csv')
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
pd.read_csv('survey_results_schema.csv')
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
pd.read_csv('result.csv', index_col= 'Respondent').Age1stCode
# Out:
# Respondent
# 1         13
# 2         19
# 3         15
# 4         18
# 5         16
#         ...
# 64858     16
# 64867    NaN
# 64898    NaN
# 64925    NaN
# 65112    NaN
# Name: Age1stCode, Length: 64461, dtype: object

# %%
pd.read_csv('survey_results_schema.csv')
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
pd.read_csv('survey_results_schema.csv')['QuestionText'][1]
# Out:
# 'Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."'

# %%
pd.read_csv('survey_results_schema.csv')['QuestionText'][10]
# Out:
# "Which currency do you use day-to-day? If your answer is complicated, please pick the one you're most comfortable estimating in."

# %%
pd.read_csv('survey_results_schema.csv', index_col= 'Column')
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
# pd.read_csv('survey_results_schema.csv', index_col= 'Column').QuestionText['Age']
# Out:
# 'What is your age (in years)? If you prefer not to answer, you may leave this question blank.'

# %%
schema_frame = 'survey_results_schema.csv'
schema_raw = pd.read_csv(schema_frame, index_col = 'Column').QuestionText
schema_raw
# Out:
# Column
# Respondent            Randomized respondent ID number (not in order ...
# MainBranch            Which of the following options best describes ...
# Hobbyist                                        Do you code as a hobby?
# Age                   What is your age (in years)? If you prefer not...
# Age1stCode            At what age did you write your first line of c...
#                                             ...
# WebframeWorkedWith    Which web frameworks have you done extensive d...
# WelcomeChange         Compared to last year, how welcome do you feel...
# WorkWeekHrs           On average, how many hours per week do you wor...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# Name: QuestionText, Length: 61, dtype: object

# %%
schema_raw.loc['YearsCodePro']
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
df = df[[ # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt']]

# %%
df.head()
# Out:
#               Country   Age Gender  \
# 0             Germany   NaN    Man
# 1      United Kingdom   NaN    NaN
# 2  Russian Federation   NaN    NaN
# 3             Albania  25.0    Man
# 4       United States  31.0    Man
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                              NaN
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                       UndergradMajor Hobbyist Age1stCode  \
# 0  Computer science, computer engineering, or sof...      Yes         13
# 1  Computer science, computer engineering, or sof...       No         19
# 2                                                NaN      Yes         15
# 3  Computer science, computer engineering, or sof...      Yes         18
# ...

# %%
df.shape
# Out:
# (64461, 20)

# %%
df.describe()
# Out:
#                 Age   WorkWeekHrs
# count  45446.000000  41151.000000
# mean      30.834111     40.782174
# std        9.585392     17.816383
# min        1.000000      1.000000
# 25%       24.000000     40.000000
# 50%       29.000000     40.000000
# 75%       35.000000     44.000000
# max      279.000000    475.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57900 non-null  object
#  7   YearsCode               57684 non-null  object
#  8   YearsCodePro            46349 non-null  object
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %%
df['Age1stCode'] = pd.to_numeric(df.Age1stCode, errors='coerce')
df['YearsCodePro'] = pd.to_numeric(df.YearsCodePro, errors='coerce')
df['YearsCode'] = pd.to_numeric(df.YearsCode, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57473 non-null  float64
#  7   YearsCode               56784 non-null  float64
#  8   YearsCodePro            44133 non-null  float64
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %%
df.dtypes
# Out:
# Country                    object
# Age                       float64
# Gender                     object
# EdLevel                    object
# UndergradMajor             object
# Hobbyist                   object
# Age1stCode                float64
# YearsCode                 float64
# YearsCodePro              float64
# LanguageWorkedWith         object
# LanguageDesireNextYear     object
# NEWLearn                   object
# NEWStuck                   object
# Employment                 object
# DevType                    object
# WorkWeekHrs               float64
# JobSat                     object
# JobFactors                 object
# NEWOvertime                object
# NEWEdImpt                  object
# dtype: object

# %%
df.loc[209]['Age1stCode']
# Out:
# nan

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
len(selected_columns)
# Out:
# 20

# %%
survey_df = df[selected_columns].copy()

# %%
schema = schema_raw[selected_columns]

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 63757 non-null  object
#  1   Age                     45192 non-null  float64
#  2   Gender                  50242 non-null  object
#  3   EdLevel                 57128 non-null  object
#  4   UndergradMajor          50739 non-null  object
#  5   Hobbyist                64101 non-null  object
#  6   Age1stCode              57171 non-null  float64
#  7   YearsCode               56484 non-null  float64
#  8   YearsCodePro            43932 non-null  float64
#  9   LanguageWorkedWith      57070 non-null  object
#  10  LanguageDesireNextYear  53822 non-null  object
#  11  NEWLearn                55862 non-null  object
#  12  NEWStuck                54676 non-null  object
#  13  Employment              63544 non-null  object
# ...

# %%
survey_df['Age1stCode'] = pd.to_numeric(survey_df.Age1stCode, errors='coerce')
survey_df['YearsCode'] = pd.to_numeric(survey_df.YearsCode, errors='coerce')
survey_df['YearsCodePro'] = pd.to_numeric(survey_df.YearsCodePro, errors='coerce')

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45192.000000  57171.000000  56484.000000  43932.000000  40959.000000
# mean      30.845990     15.486226     12.790135      8.879131     40.783021
# std        9.579533      5.113130      9.494655      7.765939     17.819472
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df.drop(df[df.Age < 5].index, inplace=True)
df.drop(df[df.Age > 100].index, inplace=True)

# %%
import matplotlib.pyplot as plt  # Importing the required module
import seaborn as sns

# %%
df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45185.000000  57167.000000  56479.000000  43928.000000  40956.000000
# mean      30.844417     15.485962     12.790772      8.879644     40.782223
# std        9.502792      5.113002      9.494734      7.766076     17.819664
# min        5.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max       99.000000     85.000000     50.000000     50.000000    475.000000

# %%
survey_df.drop(survey_df[survey_df.Age < 10].index, inplace=True)
survey_df.drop(survey_df[survey_df.Age > 100].index, inplace=True)

# %%
survey_df.drop(survey_df[survey_df.WorkWeekHrs > 140].index, inplace=True)

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
df.Gender.value_counts()
# Out:
# Gender
# Man                                                            46013
# Woman                                                           3844
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         76
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       26
# Name: count, dtype: int64

# %%
df.where(~(df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
df.Gender.value_counts()
# Out:
# Gender
# Man                                                  46013
# Woman                                                 3844
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
survey_df['Gender'].value_counts()
# Out:
# Gender
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
import numpy as np

# %%
survey_df.where(~(survey_df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
survey_df.sample(10)
# Out:
#               Country   Age Gender  \
# 47488   United States  38.0    Man
# 36524        Malaysia   NaN    NaN
# 7980            India  23.0    Man
# 395     United States   NaN    NaN
# 28318   United States   NaN    Man
# 8675          Nigeria  32.0    Man
# 45778          Canada   NaN    NaN
# 9010      Switzerland  31.0    Man
# 16138             NaN   NaN    NaN
# 56290  Czech Republic  32.0    Man
#
#                                                  EdLevel  \
# 47488       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 36524                                                NaN
# 7980        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 395      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 28318       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8675        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 45778  Some college/university study without earning ...
# 9010     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.head(200)
# Out:
#                 Country   Age Gender  \
# 0               Germany   NaN    Man
# 1        United Kingdom   NaN    NaN
# 2    Russian Federation   NaN    NaN
# 3               Albania  25.0    Man
# 4         United States  31.0    Man
# ..                  ...   ...    ...
# 195       United States  17.0    Man
# 196         Netherlands  40.0    Man
# 197              Canada  34.0  Woman
# 198       United States  53.0    Man
# 199            Pakistan  27.0    Man
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ..                                                 ...
# 195  Secondary school (e.g. American high school, G...
# 196  Some college/university study without earning ...
# ...

# %%
df.Country
# Out:
# 0                   Germany
# 1            United Kingdom
# 2        Russian Federation
# 3                   Albania
# 4             United States
#                 ...
# 64456         United States
# 64457               Morocco
# 64458              Viet Nam
# 64459                Poland
# 64460                 Spain
# Name: Country, Length: 64461, dtype: object

# %%
schema.Country
# Out:
# 'Where do you live?'

# %%
survey_df.Country.nunique()
# Out:
# 183

# %%
top_countries = df.Country.value_counts().head(15)
top_countries
# Out:
# Country
# United States         12372
# India                  8372
# United Kingdom         3883
# Germany                3875
# Canada                 2177
# France                 1889
# Brazil                 1811
# Netherlands            1335
# Poland                 1274
# Australia              1199
# Spain                  1158
# Italy                  1117
# Russian Federation     1086
# Sweden                  881
# Pakistan                803
# Name: count, dtype: int64

# %%
top_countries.index = ['USA','IND','UK','GPY','CND','FRC','BZL','NTL','PLD','AUS','SPN','ITL','RSF','SWD','PYS']
top_countries
# Out:
# USA    12372
# IND     8372
# UK      3883
# GPY     3875
# CND     2177
# FRC     1889
# BZL     1811
# NTL     1335
# PLD     1274
# AUS     1199
# SPN     1158
# ITL     1117
# RSF     1086
# SWD      881
# PYS      803
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and 'Gender' is the column you're analyzing
gender_counts = df['Gender'].value_counts()

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
#plt.title(schema.Country)
sns.barplot(x=top_countries.index, y=top_countries);

# %%
plt.figure(figsize=(12, 6))
#plt.title(schema.Age)
plt.xlabel('Age')
plt.ylabel('Number of respondents')

plt.hist(df.Age, bins=np.arange(10,80,5), color='purple');

# %%
schema.Gender
# Out:
# 'Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
gender_counts = df.Gender.value_counts()
gender_counts
# Out:
# Gender
# Man                                                  46008
# Woman                                                 3843
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title("schema.Gender")
plt.pie(gender_counts, labels=gender_counts.index, autopct='%.2f%%', startangle=360);

# %%
edgraph = df.EdLevel.value_counts()
edgraph
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          26412
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       13064
# Some college/university study without earning a degree                                 7181
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4738
# Associate degree (A.A., A.S., etc.)                                                    1834
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             1683
# Primary/elementary school                                                               933
# Professional degree (JD, MD, etc.)                                                      794
# I never completed any formal education                                                  483
# Name: count, dtype: int64

# %%
# ?sns.barplot

# %%
plt.figure(figsize=(20, 15))
#figsize is size of ur figure,
sns.barplot(x=edgraph.values, y= edgraph.index )
# Out:
# <Axes: ylabel='EdLevel'>

# %%
df.UndergradMajor.value_counts()
sns.barplot(x=df.UndergradMajor.value_counts(),y=df.UndergradMajor.value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='UndergradMajor'>

# %%
sns.countplot(y=survey_df.EdLevel)
plt.xticks(rotation=75);
plt.title(schema['EdLevel'])
plt.ylabel(None);

# %%
schema.UndergradMajor
# Out:
# 'What was your primary field of study?'

# %%
undergrad_pct = df.UndergradMajor.value_counts() * 100 / df.UndergradMajor.count()

sns.barplot(x=undergrad_pct, y=undergrad_pct.index)

plt.title(schema.UndergradMajor)
plt.ylabel(None);
plt.xlabel('Percentage');

# %%
# there is library named fulium used to vitualize graph

# %%
import folium

# %%
# ?folium.Map

# %%
countries_geojson = 'https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json'

# %%
countries_geojson
# Out:
# 'https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json'

# %%
country_counts = df.Country.value_counts()

# %%
country_counts_df = pd.DataFrame({'Country': country_counts.index, 'Count': country_counts.values})
country_counts_df
# Out:
#               Country  Count
# 0       United States  12371
# 1               India   8371
# 2      United Kingdom   3883
# 3             Germany   3875
# 4              Canada   2177
# ..                ...    ...
# 178              Fiji      1
# 179             Nauru      1
# 180           Lesotho      1
# 181       Saint Lucia      1
# 182  Marshall Islands      1
#
# [183 rows x 2 columns]

# %%
country_counts_df.at[12, 'Country']
# Out:
# 'Russian Federation'

# %%
country_counts_df.at[0, 'Country'] = 'United States of America'
country_counts_df.at[12, 'Country'] = 'Russia'
#latitude 30 deg, longitude 0 degree

# %%
m = folium.Map(location=[30, 0], zoom_start=2)
#latitude 30 deg, longitude 0 degree

folium.Choropleth(
    # Choropleth enable us to plot the graph
    geo_data=countries_geojson,
    data=country_counts_df,
    columns=["Country", "Count"],
    key_on="feature.properties.name",
    threshold_scale=[1, 30, 100, 300, 1_000, 3_000, 10_000, 13_000],
    fill_color="OrRd",
    fill_opacity=1.7,
    line_opacity=0.8,
    legend_name="Respondents",
).add_to(m)

m
#YlGn,OrRd
#.save('map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
schema.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
(survey_df.Employment.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='g')
plt.title(schema.Employment)
plt.xlabel('Percentage');

# %%
(df.Employment.value_counts(normalize=True, ascending=True)*100).plot(kind='bar', color='g')
plt.title(schema.Employment)
plt.xlabel('Percentage');
#normalize changes it to percentage value

# %%
(df.Employment.value_counts(normalize=False, ascending=True)*100).plot(kind='barh', color='g')
plt.title(schema.Employment)
plt.xlabel('Percentage');

# %%
schema.DevType
# Out:
# 'Which of the following describe you? Please select all that apply.'

# %%
df.DevType
# Out:
# 0        Developer, desktop or enterprise applications;...
# 1                  Developer, full-stack;Developer, mobile
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 64456                                  Senior executive/VP
# 64457                                                  NaN
# 64458                                                  NaN
# 64459                                                  NaN
# 64460                                                  NaN
# Name: DevType, Length: 64454, dtype: object

# %%
df.DevType.notnull()
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 64456     True
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: DevType, Length: 64454, dtype: bool

# %%
df.DevType[df.DevType.notnull()]
# Out:
# 0        Developer, desktop or enterprise applications;...
# 1                  Developer, full-stack;Developer, mobile
# 5          Designer;Developer, front-end;Developer, mobile
# 6        Developer, back-end;Developer, front-end;Devel...
# 7        Developer, back-end;Developer, desktop or ente...
#                                ...
# 64448    Developer, back-end;Developer, desktop or ente...
# 64449                                    Developer, mobile
# 64451        Data scientist or machine learning specialist
# 64453    Data or business analyst;Developer, mobile;Sen...
# 64456                                  Senior executive/VP
# Name: DevType, Length: 49119, dtype: object

# %%
dev = df.DevType.value_counts()
dev
# Out:
# DevType
# Developer, full-stack                                                                                                                                                                              4403
# Developer, back-end                                                                                                                                                                                3069
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                                     2219
# Developer, back-end;Developer, full-stack                                                                                                                                                          1468
# ...

# %%
survey_df.DevType.value_counts()
# Out:
# DevType
# Developer, full-stack                                                                                                                                                           4396
# Developer, back-end                                                                                                                                                             3056
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                  2214
# Developer, back-end;Developer, full-stack                                                                                                                                       1465
# Developer, front-end                                                                                                                                                            1390
# ...

# %%
dev.to_frame
# Out:
# <bound method Series.to_frame of DevType
# Developer, full-stack                                                                                                                                                                              4403
# Developer, back-end                                                                                                                                                                                3069
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                                     2219
# Developer, back-end;Developer, full-stack                                                                                                                                                          1468
# ...

# %%
for idx, value in col_series[col_series.notnull()].items():
    if isinstance(value, str):
        for option in value.split(';'):
# Out:
#   File "<ipython-input-167-fb25d4d2742e>", line 3
#     for option in value.split(';'):
#                                    ^
# SyntaxError: incomplete input

# %%
#for idx, value in dev[dev.notnull()].iteritems():
for idx, value  in enumerate(list(range(10, 20))):
  print(idx, '---', value)
# Out:
# 0 --- 10
# 1 --- 11
# 2 --- 12
# 3 --- 13
# 4 --- 14
# 5 --- 15
# 6 --- 16
# 7 --- 17
# 8 --- 18
# 9 --- 19

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].iteritems():
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
def split_multicolumn(col_series):
    # Convert the series into a DataFrame with one column
    result_df = col_series.to_frame()

    # Initialize an empty list to store unique options
    options = []

    # Iterate over the series where the values are not null
    for idx, value in col_series[col_series.notnull()].items():
        # Break each value into a list of options
        for option in value.split(';'):
            # Add the option as a column if it doesn't already exist
            if option not in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True

    # Return the resulting DataFrame with only the newly created option columns
    return result_df[options]

# %%
dev_type_df = split_multicolumn(survey_df.DevType)

# %%
dev_type_df
# Out:
#        Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                               True                   True
# 1                                              False                   True
# 2                                              False                  False
# 3                                              False                  False
# 4                                              False                  False
# ...                                              ...                    ...
# 64456                                          False                  False
# 64457                                          False                  False
# 64458                                          False                  False
# 64459                                          False                  False
# 64460                                          False                  False
#
# ...

# %%
dev_type_df.sum()
# Out:
# Developer, desktop or enterprise applications    11687
# Developer, full-stack                            26915
# Developer, mobile                                 9406
# Designer                                          5262
# Developer, front-end                             18128
# Developer, back-end                              26996
# Developer, QA or test                             3893
# DevOps specialist                                 5915
# Developer, game or graphics                       2751
# Database administrator                            5658
# Developer, embedded applications or devices       4701
# Engineer, data                                    3700
# Educator                                          2895
# System administrator                              5185
# Engineering manager                               2699
# Product manager                                   2471
# Data or business analyst                          3970
# ...

# %%
dev_type_df.sum().sort_values(ascending=True).plot(kind='barh',color='g')
# Out:
# <Axes: >

# %%
from google.colab import drive
drive.mount('/content/drive')
